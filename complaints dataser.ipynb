# %%
Complaints Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pip install opendatasets --upgrade --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv('complaints.csv')
df.head()
# Out:
# C:\Users\gosav\AppData\Local\Temp\ipykernel_13084\638734534.py:1: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('complaints.csv')
#   Date received                                            Product  \
# 0    2023-12-09  Credit reporting or other personal consumer re...
# 1    2023-12-09  Credit reporting or other personal consumer re...
# 2    2023-12-09                                           Mortgage
# 3    2023-12-05                                    Debt collection
# 4    2024-01-03  Credit reporting or other personal consumer re...
#
#         Sub-product                                              Issue  \
# 0  Credit reporting               Incorrect information on your report
# 1  Credit reporting                        Improper use of your report
# 2      FHA mortgage  Applying for a mortgage or refinancing an exis...
# 3     I do not know                  Attempts to collect debt not owed
# 4  Credit reporting  Problem with a company's investigation into an...
#
#                                            Sub-issue  \
# 0                Information belongs to someone else
# 1      Reporting company used your report improperly
# 2                                Application denials
# 3                                      Debt was paid
# 4  Their investigation did not fix an error on yo...
#
#   Consumer complaint narrative Company public response  \
# 0                          NaN                     NaN
# 1                          NaN                     NaN
# 2                          NaN                     NaN
# 3                          NaN                     NaN
# 4                          NaN                     NaN
#
#                                Company State ZIP code Tags  \
# 0                        EQUIFAX, INC.    AZ    85379  NaN
# 1  Experian Information Solutions Inc.    WA    98296  NaN
# 2          Home American Mortgage Corp    UT    84664  NaN
# 3                            Elly, LLC    MA    02703  NaN
# 4                        EQUIFAX, INC.    CA    90723  NaN
#
#   Consumer consent provided? Submitted via Date sent to company  \
# 0                      Other           Web           2023-12-09
# 1                        NaN           Web           2023-12-09
# 2                        NaN           Web           2023-12-09
# 3                        NaN           Web           2023-12-05
# 4                        NaN           Web           2024-01-03
#
#   Company response to consumer Timely response? Consumer disputed?  \
# 0                  In progress              Yes                NaN
# 1                  In progress              Yes                NaN
# 2      Closed with explanation              Yes                NaN
# 3            Untimely response               No                NaN
# 4                  In progress              Yes                NaN
#
#    Complaint ID
# 0       7968391
# 1       7968343
# 2       7968437
# 3       7949742
# 4       8095676

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4496055 entries, 0 to 4496054
# Data columns (total 18 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   Date received                 object
#  1   Product                       object
#  2   Sub-product                   object
#  3   Issue                         object
#  4   Sub-issue                     object
#  5   Consumer complaint narrative  object
#  6   Company public response       object
#  7   Company                       object
#  8   State                         object
#  9   ZIP code                      object
#  10  Tags                          object
#  11  Consumer consent provided?    object
#  12  Submitted via                 object
#  13  Date sent to company          object
#  14  Company response to consumer  object
#  15  Timely response?              object
#  16  Consumer disputed?            object
#  17  Complaint ID                  int64
# dtypes: int64(1), object(17)
# memory usage: 617.4+ MB

# %%
df.describe()
# Out:
#        Complaint ID
# count  4.496055e+06
# mean   4.655213e+06
# std    2.183115e+06
# min    1.000000e+00
# 25%    3.016606e+06
# 50%    4.678594e+06
# 75%    6.599434e+06
# max    8.102564e+06

# %%
df.isna().sum()
# Out:
# Date received                         0
# Product                               0
# Sub-product                      235291
# Issue                                 0
# Sub-issue                        724454
# Consumer complaint narrative    2864936
# Company public response         2368592
# Company                               0
# State                             43902
# ZIP code                          30223
# Tags                            4045483
# Consumer consent provided?       914488
# Submitted via                         0
# Date sent to company                  0
# Company response to consumer         10
# Timely response?                      0
# Consumer disputed?              3727700
# Complaint ID                          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.Tags.value_counts()
# Out:
# Servicemember                    262651
# Older American                   151050
# Older American, Servicemember     36871
# Name: Tags, dtype: int64

# %%
df.Issue.value_counts()
# Out:
# Incorrect information on your report                                                1230877
# Improper use of your report                                                          628513
# Problem with a credit reporting company's investigation into an existing problem     589339
# Attempts to collect debt not owed                                                    192059
# Managing an account                                                                  119561
#                                                                                      ...
# Lender damaged or destroyed vehicle                                                       8
# Problems receiving the advance                                                            8
# Property was damaged or destroyed property                                                7
# Lender sold the property                                                                  7
# Lender damaged or destroyed property                                                      3
# Name: Issue, Length: 177, dtype: int64

# %%
df.Product.value_counts()
# Out:
# Credit reporting, credit repair services, or other personal consumer reports    2163891
# Debt collection                                                                  526160
# Credit reporting or other personal consumer reports                              397927
# Mortgage                                                                         390236
# Credit card or prepaid card                                                      206374
# Checking or savings account                                                      195854
# Credit reporting                                                                 140429
# Credit card                                                                      109839
# Bank account or service                                                           86205
# Student loan                                                                      82398
# Money transfer, virtual currency, or money service                                62871
# Vehicle loan or lease                                                             51062
# Consumer Loan                                                                     31575
# Payday loan, title loan, or personal loan                                         30640
# Prepaid card                                                                       5785
# Payday loan                                                                        5541
# Money transfers                                                                    5354
# Payday loan, title loan, personal loan, or advance loan                            2387
# Other financial service                                                            1058
# Debt or credit management                                                           451
# Virtual currency                                                                     18
# Name: Product, dtype: int64

# %%
df.corr()
# Out:
#               Complaint ID
# Complaint ID           1.0

# %%
plt.figure(figsize=(15,12))
sns.heatmap(df.corr(),annot = True)
plt.show()

# %%
plt.hist(df.Product)
plt.show()

# %%
df.dtypes
# Out:
# Date received                   object
# Product                         object
# Sub-product                     object
# Issue                           object
# Sub-issue                       object
# Consumer complaint narrative    object
# Company public response         object
# Company                         object
# State                           object
# ZIP code                        object
# Tags                            object
# Consumer consent provided?      object
# Submitted via                   object
# Date sent to company            object
# Company response to consumer    object
# Timely response?                object
# Consumer disputed?              object
# Complaint ID                     int64
# dtype: object

# %%
df.drop(['Product','Sub-product','Issue','State'],axis=1,inplace=True)
df
# Out:
#         Date received                                          Sub-issue  \
# 0          2023-12-09                Information belongs to someone else
# 1          2023-12-09      Reporting company used your report improperly
# 2          2023-12-09                                Application denials
# 3          2023-12-05                                      Debt was paid
# 4          2024-01-03  Their investigation did not fix an error on yo...
# ...               ...                                                ...
# 4496050    2023-07-21                Information belongs to someone else
# 4496051    2023-07-21                Information belongs to someone else
# 4496052    2023-07-21       Old information reappears or never goes away
# 4496053    2023-07-20                Information belongs to someone else
# 4496054    2023-07-20                Information belongs to someone else
#
#         Consumer complaint narrative  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 4496050                          NaN
# 4496051                          NaN
# 4496052                          NaN
# 4496053                          NaN
# 4496054                          NaN
#
#                                    Company public response  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 4496050  Company has responded to the consumer and the ...
# 4496051  Company has responded to the consumer and the ...
# 4496052  Company has responded to the consumer and the ...
# 4496053  Company has responded to the consumer and the ...
# 4496054  Company has responded to the consumer and the ...
#
#                                      Company ZIP code Tags  \
# 0                              EQUIFAX, INC.    85379  NaN
# 1        Experian Information Solutions Inc.    98296  NaN
# 2                Home American Mortgage Corp    84664  NaN
# 3                                  Elly, LLC    02703  NaN
# 4                              EQUIFAX, INC.    90723  NaN
# ...                                      ...      ...  ...
# 4496050  Experian Information Solutions Inc.    19140  NaN
# 4496051  Experian Information Solutions Inc.    21202  NaN
# 4496052  Experian Information Solutions Inc.    38666  NaN
# 4496053  Experian Information Solutions Inc.    43068  NaN
# 4496054  Experian Information Solutions Inc.    11207  NaN
#
#         Consumer consent provided? Submitted via Date sent to company  \
# 0                            Other           Web           2023-12-09
# 1                              NaN           Web           2023-12-09
# 2                              NaN           Web           2023-12-09
# 3                              NaN           Web           2023-12-05
# 4                              NaN           Web           2024-01-03
# ...                            ...           ...                  ...
# 4496050       Consent not provided           Web           2023-07-21
# 4496051       Consent not provided           Web           2023-07-21
# 4496052       Consent not provided           Web           2023-07-21
# 4496053       Consent not provided           Web           2023-07-20
# 4496054       Consent not provided           Web           2023-07-20
#
#             Company response to consumer Timely response? Consumer disputed?  \
# 0                            In progress              Yes                NaN
# 1                            In progress              Yes                NaN
# 2                Closed with explanation              Yes                NaN
# 3                      Untimely response               No                NaN
# 4                            In progress              Yes                NaN
# ...                                  ...              ...                ...
# 4496050          Closed with explanation              Yes                NaN
# 4496051          Closed with explanation              Yes                NaN
# 4496052  Closed with non-monetary relief              Yes                NaN
# 4496053          Closed with explanation              Yes                NaN
# 4496054          Closed with explanation              Yes                NaN
#
#          Complaint ID
# 0             7968391
# 1             7968343
# 2             7968437
# 3             7949742
# 4             8095676
# ...               ...
# 4496050       7286110
# 4496051       7286165
# 4496052       7283012
# 4496053       7280776
# 4496054       7270026
#
# [4496055 rows x 14 columns]

# %%
df.columns
# Out:
# Index(['Date received', 'Sub-issue', 'Consumer complaint narrative',
#        'Company public response', 'Company', 'ZIP code', 'Tags',
#        'Consumer consent provided?', 'Submitted via', 'Date sent to company',
#        'Company response to consumer', 'Timely response?',
#        'Consumer disputed?', 'Complaint ID'],
#       dtype='object')

# %%
for col in df.columns:
    if df[col].dtype == 'object':
        df[col] = pd.Categorical(df[col]).codes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4496055 entries, 0 to 4496054
# Data columns (total 14 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   Date received                 int16
#  1   Sub-issue                     int16
#  2   Consumer complaint narrative  int32
#  3   Company public response       int8
#  4   Company                       int16
#  5   ZIP code                      int32
#  6   Tags                          int8
#  7   Consumer consent provided?    int8
#  8   Submitted via                 int8
#  9   Date sent to company          int16
#  10  Company response to consumer  int8
#  11  Timely response?              int8
#  12  Consumer disputed?            int8
#  13  Complaint ID                  int64
# dtypes: int16(4), int32(2), int64(1), int8(7)
# memory usage: 132.9 MB

# %%
df[['Tags','Company']] = df[['Tags','Company']].replace('unknown','other')
df
# Out:
#          Date received  Sub-issue  Consumer complaint narrative  \
# 0                 4389        124                            -1
# 1                 4389        226                            -1
# 2                 4389         11                            -1
# 3                 4385         79                            -1
# 4                 4414        239                            -1
# ...                ...        ...                           ...
# 4496050           4248        124                            -1
# 4496051           4248        124                            -1
# 4496052           4248        155                            -1
# 4496053           4247        124                            -1
# 4496054           4247        124                            -1
#
#          Company public response  Company  ZIP code  Tags  \
# 0                             -1     2228     28652    -1
# 1                             -1     2401     32761    -1
# 2                             -1     3204     28353    -1
# 3                             -1     2314       830    -1
# 4                             -1     2228     29696    -1
# ...                          ...      ...       ...   ...
# 4496050                       10     2401      6470    -1
# 4496051                       10     2401      7179    -1
# 4496052                       10     2401     14275    -1
# 4496053                       10     2401     15392    -1
# 4496054                       10     2401      3503    -1
#
#          Consumer consent provided?  Submitted via  Date sent to company  \
# 0                                 3              5                  4338
# 1                                -1              5                  4338
# 2                                -1              5                  4338
# 3                                -1              5                  4334
# 4                                -1              5                  4363
# ...                             ...            ...                   ...
# 4496050                           0              5                  4197
# 4496051                           0              5                  4197
# 4496052                           0              5                  4197
# 4496053                           0              5                  4196
# 4496054                           0              5                  4196
#
#          Company response to consumer  Timely response?  Consumer disputed?  \
# 0                                   6                 1                  -1
# 1                                   6                 1                  -1
# 2                                   1                 1                  -1
# 3                                   7                 0                  -1
# 4                                   6                 1                  -1
# ...                               ...               ...                 ...
# 4496050                             1                 1                  -1
# 4496051                             1                 1                  -1
# 4496052                             3                 1                  -1
# 4496053                             1                 1                  -1
# 4496054                             1                 1                  -1
#
#          Complaint ID
# 0             7968391
# 1             7968343
# 2             7968437
# 3             7949742
# 4             8095676
# ...               ...
# 4496050       7286110
# 4496051       7286165
# 4496052       7283012
# 4496053       7280776
# 4496054       7270026
#
# [4496055 rows x 14 columns]

# %%
df.hist(figsize=(10,8))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x = df.drop('Tags',axis=1)
y= df['Tags']

# %%
X
# Out:
#          Date received  Sub-issue  Consumer complaint narrative  \
# 0                 4389        124                            -1
# 1                 4389        226                            -1
# 2                 4389         11                            -1
# 3                 4385         79                            -1
# 4                 4414        239                            -1
# ...                ...        ...                           ...
# 4496050           4248        124                            -1
# 4496051           4248        124                            -1
# 4496052           4248        155                            -1
# 4496053           4247        124                            -1
# 4496054           4247        124                            -1
#
#          Company public response  Company  ZIP code  \
# 0                             -1     2228     28652
# 1                             -1     2401     32761
# 2                             -1     3204     28353
# 3                             -1     2314       830
# 4                             -1     2228     29696
# ...                          ...      ...       ...
# 4496050                       10     2401      6470
# 4496051                       10     2401      7179
# 4496052                       10     2401     14275
# 4496053                       10     2401     15392
# 4496054                       10     2401      3503
#
#          Consumer consent provided?  Submitted via  Date sent to company  \
# 0                                 3              5                  4338
# 1                                -1              5                  4338
# 2                                -1              5                  4338
# 3                                -1              5                  4334
# 4                                -1              5                  4363
# ...                             ...            ...                   ...
# 4496050                           0              5                  4197
# 4496051                           0              5                  4197
# 4496052                           0              5                  4197
# 4496053                           0              5                  4196
# 4496054                           0              5                  4196
#
#          Company response to consumer  Timely response?  Consumer disputed?  \
# 0                                   6                 1                  -1
# 1                                   6                 1                  -1
# 2                                   1                 1                  -1
# 3                                   7                 0                  -1
# 4                                   6                 1                  -1
# ...                               ...               ...                 ...
# 4496050                             1                 1                  -1
# 4496051                             1                 1                  -1
# 4496052                             3                 1                  -1
# 4496053                             1                 1                  -1
# 4496054                             1                 1                  -1
#
#          Complaint ID
# 0             7968391
# 1             7968343
# 2             7968437
# 3             7949742
# 4             8095676
# ...               ...
# 4496050       7286110
# 4496051       7286165
# 4496052       7283012
# 4496053       7280776
# 4496054       7270026
#
# [4496055 rows x 13 columns]

# %%
y
# Out:
# 0         -1
# 1         -1
# 2         -1
# 3         -1
# 4         -1
#           ..
# 4496050   -1
# 4496051   -1
# 4496052   -1
# 4496053   -1
# 4496054   -1
# Name: Tags, Length: 4496055, dtype: int8

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size = 0.25,random_state = 42)

# %%
df.shape
# Out:
# (4496055, 14)

# %%
X_train
# Out:
#          Date received  Sub-issue  Consumer complaint narrative  \
# 581166             330         -1                            -1
# 2126928           3020          0                         61879
# 3201185           1994        108                            -1
# 389303            4203        155                            -1
# 321419            4343         75                            -1
# ...                ...        ...                           ...
# 1136074           2813         -1                            -1
# 1570006           2951        169                        901781
# 2234489           4095        131                        473663
# 4304572           3897          0                        759620
# 1692743           4315        124                       1114949
#
#          Company public response  Company  ZIP code  \
# 581166                        -1     6846     24725
# 2126928                       -1     4439     33305
# 3201185                       -1     4622     19271
# 389303                        -1     4622      6715
# 321419                        10     2401      6461
# ...                          ...      ...       ...
# 1136074                       10     6846        -1
# 1570006                       10      850     21069
# 2234489                       10     2401     12953
# 4304572                       -1     2228     17464
# 1692743                       -1     2228     33305
#
#          Consumer consent provided?  Submitted via  Date sent to company  \
# 581166                           -1              3                   285
# 2126928                           1              5                  2969
# 3201185                           0              5                  1944
# 389303                            0              5                  4152
# 321419                            0              5                  4292
# ...                             ...            ...                   ...
# 1136074                          -1              4                  2762
# 1570006                           1              5                  2900
# 2234489                           1              5                  4044
# 4304572                           1              5                  3847
# 1692743                           1              5                  4264
#
#          Company response to consumer  Timely response?  Consumer disputed?  \
# 581166                              3                 1                   0
# 2126928                             1                 1                  -1
# 3201185                             1                 1                  -1
# 389303                              1                 1                  -1
# 321419                              1                 1                  -1
# ...                               ...               ...                 ...
# 1136074                             1                 1                  -1
# 1570006                             1                 1                  -1
# 2234489                             1                 1                  -1
# 4304572                             1                 1                  -1
# 1692743                             3                 1                  -1
#
#          Complaint ID
# 581166         178950
# 2126928       3559912
# 3201185       2487919
# 389303        7080512
# 321419        7743150
# ...               ...
# 1136074       3342001
# 1570006       3482055
# 2234489       6588826
# 4304572       5842952
# 1692743       7600787
#
# [3372041 rows x 13 columns]

# %%
X_test
# Out:
#          Date received  Sub-issue  Consumer complaint narrative  \
# 529196            3525        126                        156893
# 1254836           4233        131                        417039
# 3681635           1939         -1                        947371
# 2415082           4080        124                        753855
# 1764227           3751          6                       1166735
# ...                ...        ...                           ...
# 3924763           1343         -1                            -1
# 3423661           3995         70                            -1
# 417862            4342         79                       1154940
# 2437820           3817        124                            -1
# 528960            4247        226                            -1
#
#          Company public response  Company  ZIP code  \
# 529196                        10     2401     24743
# 1254836                       10     6309     33305
# 3681635                       -1     3034     13719
# 2415082                       10     2401     31123
# 1764227                       10     2401     17177
# ...                          ...      ...       ...
# 3924763                       -1     1116     29527
# 3423661                       10     2401      6976
# 417862                        -1     1116     30364
# 2437820                       -1     2228     12052
# 528960                        -1     4183     11485
#
#          Consumer consent provided?  Submitted via  Date sent to company  \
# 529196                            1              5                  3474
# 1254836                           1              5                  4182
# 3681635                           1              5                  1888
# 2415082                           1              5                  4029
# 1764227                           1              5                  3700
# ...                             ...            ...                   ...
# 3924763                          -1              4                  1293
# 3423661                           0              5                  3944
# 417862                            1              5                  4291
# 2437820                           3              5                  3766
# 528960                            0              5                  4211
#
#          Company response to consumer  Timely response?  Consumer disputed?  \
# 529196                              1                 1                  -1
# 1254836                             3                 1                  -1
# 3681635                             1                 1                   0
# 2415082                             3                 1                  -1
# 1764227                             3                 1                  -1
# ...                               ...               ...                 ...
# 3924763                             1                 1                   0
# 3423661                             3                 1                  -1
# 417862                              1                 1                  -1
# 2437820                             1                 1                  -1
# 528960                              1                 1                  -1
#
#          Complaint ID
# 529196        4579011
# 1254836       7211447
# 3681635       2401083
# 2415082       6530508
# 1764227       5306434
# ...               ...
# 3924763       1503904
# 3423661       6184007
# 417862        7743534
# 2437820       5565899
# 528960        7280343
#
# [1124014 rows x 13 columns]

# %%
y_train.shape
# Out:
# (3372041,)

# %%
y_test
# Out:
# 529196    -1
# 1254836   -1
# 3681635    1
# 2415082   -1
# 1764227   -1
#           ..
# 3924763   -1
# 3423661   -1
# 417862     0
# 2437820   -1
# 528960    -1
# Name: Tags, Length: 1124014, dtype: int8

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([-0.77536587, -0.77108981, -0.62293447, ..., -0.63340126,
#        -0.76754487, -0.88265629])

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error,r2_score
print(mean_squared_error(y_pred,y_test))
# Out:
# 0.5340969669278165

# %%
print(mean_absolute_error(y_pred,y_test))
# Out:
# 0.39728052751705956

# %%
r2_score(y_pred,y_test)
# Out:
# -65.18773254658777
